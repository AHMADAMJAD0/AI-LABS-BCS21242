# %% [markdown]
# <a href="https://colab.research.google.com/github/AHMADAMJAD0/AI-LABS-BCS21242/blob/main/new_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hy")
# Out:
# hy

# %%
print("ahmad")
# Out:
# ahmad

# %%
print("output")
# Out:
# output

# %%
print("equilient")
# Out:
# equilient
